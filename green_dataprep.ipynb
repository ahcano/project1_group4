# %% [markdown]
#  #  Data Collection and Preparation
#  ---
# * Data is collected from APIs by using Python.
#
# * Data is cleaned and prepared for the analysis by using Python and Pandas libraries.

# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
#from MCForecastTools import MCSimulation
import hvplot.pandas
# %matplotlib inline

# %%
# LOAD ENV FILE
load_dotenv(r"C:\Users\juddm\OneDrive\Desktop\School\example.env")
# Out:
# True

# %%
# Setup Alpaca API environment
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2"
)

# %% [markdown]
# ## 50 stocks from First Trust NASDAQ® Clean Edge® Green Energy Index
# Read the daily prices and clean the data.

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 3 year, between now and 365 days ago.
start_date = pd.Timestamp("2022-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()
#my subscription does not allow pulling data from the last 15min with end_date = pd.Timestamp.now().date() 

# Set the stock tickers
tickers_1 = ["TSLA", "RIVN", "ON", "LCID", "OLED", "ALGM", "POWI", "WOLF", "ENS", "AEIS", "BE", "VICR", "HASI", "NVTS", "GGR", "LICY"]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
df_Manufacturing_other = api.get_bars(
    tickers_1,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
df_Manufacturing_other.sample(10)
# Out:
#                             close     high       low  trade_count     open  \
# timestamp
# 2022-12-23 05:00:00+00:00   72.27   73.390   70.2500        19394   72.740
# 2022-06-17 04:00:00+00:00   26.24   27.170   25.5900       135793   26.545
# 2022-03-16 04:00:00+00:00   23.62   23.895   22.1300       187957   22.130
# 2023-10-06 04:00:00+00:00    6.43    6.455    6.1700        10132    6.210
# 2022-06-03 04:00:00+00:00   25.08   25.490   24.6500        12391   25.140
# 2022-09-07 04:00:00+00:00   39.46   39.730   37.9346         7419   38.000
# 2022-09-14 04:00:00+00:00   67.78   68.090   66.5450        13613   67.370
# 2023-02-27 05:00:00+00:00   72.50   73.550   71.8700        21383   73.000
# 2022-06-01 04:00:00+00:00  740.37  771.980  730.9200       663700  755.160
# 2023-09-29 04:00:00+00:00  250.22  254.770  246.3500      1255461  250.000
#
#                               volume        vwap symbol
# timestamp
# 2022-12-23 05:00:00+00:00    1230734   71.876890   WOLF
# ...

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 3 year, between now and 365 days ago.
start_date = pd.Timestamp("2022-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers_2 = ["FSLR", "ENPH", "SEDG", "BEP", "ARRY", "ORA", "PLUG", "SHLS", "ITRI", "RUN", "NXT", "NEP", "AY", "CWEN", "RNW", "AMRC", "NOVA", "SPWR", "CLNE", "AMPS", "STEM", "FCEL", "MAXN" ]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
df_Renewable = api.get_bars(
    tickers_2,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
df_Renewable.sample(10)
# Out:
#                             close     high     low  trade_count    open  \
# timestamp
# 2023-07-17 04:00:00+00:00    6.50    6.720    5.94        20890    6.09
# 2022-11-18 05:00:00+00:00   15.84   16.740   15.47        86809   16.57
# 2023-08-15 04:00:00+00:00   46.42   47.270   46.27        15409   46.66
# 2023-06-13 04:00:00+00:00   10.91   11.110   10.48       210393   10.73
# 2023-01-13 05:00:00+00:00  315.02  316.789  303.01        18788  303.01
# 2022-07-05 04:00:00+00:00   76.48   79.780   75.25        18785   79.16
# 2022-04-06 04:00:00+00:00    7.77    8.130    7.60        25456    8.05
# 2023-01-04 05:00:00+00:00   17.64   17.750   15.87         8850   16.20
# 2022-03-28 04:00:00+00:00   14.37   14.410   12.97         8809   13.00
# 2023-06-16 04:00:00+00:00   23.95   24.240   23.70        10704   24.15
#
#                              volume        vwap symbol
# timestamp
# 2023-07-17 04:00:00+00:00   2930227    6.517292   AMPS
# ...

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 3 year, between now and 365 days ago.
start_date = pd.Timestamp("2022-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers_3 = ["ALB", "AYI", "LTHM", "MP", "SQM", "FLNC", "CHPT", "MNTK", "BLDP", "LNZA", "ALLG"]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
df_Resources = api.get_bars(
    tickers_3,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
df_Resources.sample(10)
# Out:
#                             close     high       low  trade_count    open  \
# timestamp
# 2023-05-19 04:00:00+00:00    3.34    3.490    3.3400          503    3.48
# 2023-08-21 04:00:00+00:00   20.57   20.770   20.1600        29939   20.60
# 2022-09-19 04:00:00+00:00   18.58   18.960   17.7600        10823   18.00
# 2023-03-30 04:00:00+00:00   81.40   85.025   80.3100        25526   84.62
# 2022-09-29 04:00:00+00:00   14.93   15.860   14.3800        58687   15.51
# 2022-02-10 05:00:00+00:00   13.92   14.880   13.4115        85279   13.55
# 2023-08-18 04:00:00+00:00  158.06  159.550  157.0700         6987  158.44
# 2022-05-25 04:00:00+00:00    8.34    8.510    8.0400          959    8.14
# 2022-01-20 05:00:00+00:00  200.08  207.900  200.0500         7278  205.01
# 2023-09-28 04:00:00+00:00    5.30    5.750    5.2400         5329    5.56
#
#                              volume        vwap symbol
# timestamp
# 2023-05-19 04:00:00+00:00     38839    3.403481   LNZA
# ...

# %%
# Using the df_ticker DataFrame, create a DataFrame consisting of timestamp, close and symbol columns

df_Manufacturing_other = df_Manufacturing_other [ ["close", "symbol"]]

df_Renewable = df_Renewable [  ["close", "symbol"]]

df_Resources = df_Resources [ ["close", "symbol"]]
# View the DataFrame
df_Manufacturing_other.sample(10)
# Out:
#                             close symbol
# timestamp
# 2023-01-20 05:00:00+00:00    7.82   LCID
# 2022-07-19 04:00:00+00:00   58.78     ON
# 2023-05-30 04:00:00+00:00   49.83   WOLF
# 2022-12-19 05:00:00+00:00   52.46   VICR
# 2023-05-10 04:00:00+00:00   80.96   POWI
# 2022-05-06 04:00:00+00:00   25.29   ALGM
# 2023-05-30 04:00:00+00:00   83.97     ON
# 2023-04-14 04:00:00+00:00  185.00   TSLA
# 2023-07-17 04:00:00+00:00  290.38   TSLA
# 2023-07-24 04:00:00+00:00  108.32    ENS

# %%
# Adjust resources dataframe so tickers serve as column titles
ALB = df_Resources[df_Resources["symbol"]=="ALB"].drop("symbol", axis=1)
AYI = df_Resources[df_Resources["symbol"]=="AYI"].drop("symbol", axis=1)
LTHM = df_Resources[df_Resources["symbol"]=="LTHM"].drop("symbol", axis=1)
MP = df_Resources[df_Resources["symbol"]=="MP"].drop("symbol", axis=1)
SQM = df_Resources[df_Resources["symbol"]=="SQM"].drop("symbol", axis=1)
FLNC = df_Resources[df_Resources["symbol"]=="FLNC"].drop("symbol", axis=1)
CHPT = df_Resources[df_Resources["symbol"]=="CHPT"].drop("symbol", axis=1)
MNTK = df_Resources[df_Resources["symbol"]=="MNTK"].drop("symbol", axis=1)
BLDP = df_Resources[df_Resources["symbol"]=="BLDP"].drop("symbol", axis=1)
LNZA = df_Resources[df_Resources["symbol"]=="LNZA"].drop("symbol", axis=1)
ALLG = df_Resources[df_Resources["symbol"]=="ALLG"].drop("symbol", axis=1)

# Concatenate the ticker DataFrames
df_Resources = pd.concat([ALB, AYI, LTHM, MP, SQM, FLNC, CHPT, MNTK, BLDP, LNZA, ALLG], axis=1, keys=["ALB", "AYI", "LTHM", "MP", "SQM", "FLNC", "CHPT", "MNTK", "BLDP", "LNZA", "ALLG"])

# Display sample data
df_Resources
# Out:
#                               ALB     AYI   LTHM     MP    SQM   FLNC   CHPT  \
#                             close   close  close  close  close  close  close
# timestamp
# 2022-01-03 05:00:00+00:00  236.67  213.09  25.52  47.65  50.73  34.87  19.87
# 2022-01-04 05:00:00+00:00  242.58  216.70  26.43  50.40  49.10  34.85  19.52
# 2022-01-05 05:00:00+00:00  235.64  213.06  24.20  45.51  47.66  30.23  18.16
# 2022-01-06 05:00:00+00:00  233.38  210.69  23.73  45.31  49.06  28.06  17.35
# 2022-01-07 05:00:00+00:00  236.02  214.63  23.80  45.52  49.96  27.40  16.89
# ...                           ...     ...    ...    ...    ...    ...    ...
# 2023-10-02 04:00:00+00:00  162.41  167.17  17.44  18.53  56.24  22.38   4.75
# 2023-10-03 04:00:00+00:00  156.77  167.38  16.82  17.60  54.56  20.42   4.38
# 2023-10-04 04:00:00+00:00  158.40  179.00  17.38  17.36  55.04  21.10   4.40
# 2023-10-05 04:00:00+00:00  155.03  179.00  16.88  16.83  53.07  20.62   4.16
# ...

# %%
# Adjust manufacturing dataframe so tickers serve as column titles
TSLA = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="TSLA"].drop("symbol", axis=1)
RIVN = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="RIVN"].drop("symbol", axis=1)
ON = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="ON"].drop("symbol", axis=1)
LCID = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="LCID"].drop("symbol", axis=1)
OLED = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="OLED"].drop("symbol", axis=1)
ALGM = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="ALGM"].drop("symbol", axis=1)
POWI = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="POWI"].drop("symbol", axis=1)
WOLF = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="WOLF"].drop("symbol", axis=1)
ENS = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="ENS"].drop("symbol", axis=1)
AEIS = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="AEIS"].drop("symbol", axis=1)
BE = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="BE"].drop("symbol", axis=1)
VICR = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="VICR"].drop("symbol", axis=1)
HASI = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="HASI"].drop("symbol", axis=1)
NVTS = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="NVTS"].drop("symbol", axis=1)
GGR = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="GGR"].drop("symbol", axis=1)
LICY = df_Manufacturing_other[df_Manufacturing_other["symbol"]=="LICY"].drop("symbol", axis=1)

["TSLA", "RIVN", "ON", "LCID", "OLED", "ALGM", "POWI", "WOLF", "ENS", "AEIS", "BE", "VICR", "HASI", "NVTS", "GGR", "LICY"]

# Concatenate the ticker DataFrames
df_Manufacturing_other = pd.concat([TSLA, RIVN, ON, LCID, OLED, ALGM, POWI, WOLF, ENS, AEIS, BE, VICR, HASI, NVTS, GGR, LICY], axis=1, keys=["TSLA", "RIVN", "ON", "LCID", "OLED", "ALGM", "POWI", "WOLF", "ENS", "AEIS", "BE", "VICR", "HASI", "NVTS", "GGR", "LICY"])

# Display sample data
df_Manufacturing_other
# Out:
#                               TSLA    RIVN     ON   LCID    OLED   ALGM  \
#                              close   close  close  close   close  close
# timestamp
# 2022-01-03 05:00:00+00:00  1199.78  102.72  70.17  40.93  171.41  36.41
# 2022-01-04 05:00:00+00:00  1149.59  101.39  70.95  39.41  175.26  35.28
# 2022-01-05 05:00:00+00:00  1088.12   90.01  67.42  36.68  166.11  33.21
# 2022-01-06 05:00:00+00:00  1064.70   87.33  67.25  38.22  164.74  32.97
# 2022-01-07 05:00:00+00:00  1026.96   86.28  64.56  41.98  158.85  32.17
# ...                            ...     ...    ...    ...     ...    ...
# 2023-10-02 04:00:00+00:00   251.60   23.66  93.37   5.54  156.05  31.89
# 2023-10-03 04:00:00+00:00   246.53   21.69  89.76   5.38  153.86  29.98
# 2023-10-04 04:00:00+00:00   261.16   23.69  89.99   5.56  156.15  30.92
# 2023-10-05 04:00:00+00:00   260.05   18.27  88.17   5.16  155.68  30.37
# 2023-10-06 04:00:00+00:00   260.53   18.92  90.93   5.13  158.78  30.92
#
# ...

# %%
# Adjust Renewable and other dataframe so tickers serve as column titles
FSLR = df_Renewable[df_Renewable["symbol"]=="FSLR"].drop("symbol", axis=1)
ENPH = df_Renewable[df_Renewable["symbol"]=="ENPH"].drop("symbol", axis=1)
SEDG = df_Renewable[df_Renewable["symbol"]=="SEDG"].drop("symbol", axis=1)
BEP = df_Renewable[df_Renewable["symbol"]=="BEP"].drop("symbol", axis=1)
ARRY = df_Renewable[df_Renewable["symbol"]=="ARRY"].drop("symbol", axis=1)
ORA = df_Renewable[df_Renewable["symbol"]=="ORA"].drop("symbol", axis=1)
PLUG = df_Renewable[df_Renewable["symbol"]=="PLUG"].drop("symbol", axis=1)
SHLS = df_Renewable[df_Renewable["symbol"]=="SHLS"].drop("symbol", axis=1)
ITRI = df_Renewable[df_Renewable["symbol"]=="ITRI"].drop("symbol", axis=1)
RUN = df_Renewable[df_Renewable["symbol"]=="RUN"].drop("symbol", axis=1)
NXT = df_Renewable[df_Renewable["symbol"]=="NXT"].drop("symbol", axis=1)
NEP = df_Renewable[df_Renewable["symbol"]=="NEP"].drop("symbol", axis=1)
AY = df_Renewable[df_Renewable["symbol"]=="AY"].drop("symbol", axis=1)
CWEN = df_Renewable[df_Renewable["symbol"]=="CWEN"].drop("symbol", axis=1)
RNW = df_Renewable[df_Renewable["symbol"]=="RNW"].drop("symbol", axis=1)
AMRC = df_Renewable[df_Renewable["symbol"]=="AMRC"].drop("symbol", axis=1)
NOVA = df_Renewable[df_Renewable["symbol"]=="NOVA"].drop("symbol", axis=1)
SPWR = df_Renewable[df_Renewable["symbol"]=="SPWR"].drop("symbol", axis=1)
CLNE = df_Renewable[df_Renewable["symbol"]=="CLNE"].drop("symbol", axis=1)
AMPS = df_Renewable[df_Renewable["symbol"]=="AMPS"].drop("symbol", axis=1)
STEM = df_Renewable[df_Renewable["symbol"]=="STEM"].drop("symbol", axis=1)
FCEL = df_Renewable[df_Renewable["symbol"]=="FCEL"].drop("symbol", axis=1)
MAXN = df_Renewable[df_Renewable["symbol"]=="MAXN"].drop("symbol", axis=1)

# Concatenate the ticker DataFrames
df_Renewable = pd.concat([FSLR, ENPH, SEDG, BEP, ARRY, ORA, PLUG, SHLS, ITRI, RUN, NXT, NEP, AY, CWEN, RNW, AMRC, NOVA, SPWR, CLNE, AMPS, STEM, FCEL, MAXN], axis=1, keys=["FSLR", "ENPH", "SEDG", "BEP", "ARRY", "ORA", "PLUG", "SHLS", "ITRI", "RUN", "NXT", "NEP", "AY", "CWEN", "RNW", "AMRC", "NOVA", "SPWR", "CLNE", "AMPS", "STEM", "FCEL", "MAXN"])

# Display sample data
df_Renewable
# Out:
#                              FSLR    ENPH    SEDG    BEP    ARRY    ORA  \
#                             close   close   close  close   close  close
# timestamp
# 2022-01-03 05:00:00+00:00   88.58  184.45  282.45  35.85  15.910  78.55
# 2022-01-04 05:00:00+00:00   87.28  178.28  273.10  35.21  14.970  78.83
# 2022-01-05 05:00:00+00:00   83.51  157.20  249.81  34.05  13.920  76.82
# 2022-01-06 05:00:00+00:00   83.97  151.49  248.24  33.42  13.840  76.69
# 2022-01-07 05:00:00+00:00   84.68  145.13  248.91  34.12  14.120  75.99
# ...                           ...     ...     ...    ...     ...    ...
# 2023-10-02 04:00:00+00:00  156.34  116.84  122.56  20.44  21.360  68.18
# 2023-10-03 04:00:00+00:00  151.25  114.22  120.31  20.33  19.545  67.26
# 2023-10-04 04:00:00+00:00  151.82  117.18  125.31  20.87  20.330  68.72
# 2023-10-05 04:00:00+00:00  145.35  116.01  120.62  21.17  18.830  66.06
# 2023-10-06 04:00:00+00:00  148.56  119.16  123.97  21.31  19.750  67.63
#
# ...

# %% [markdown]
# ## First Trust NASDAQ® Clean Edge® Green Energy Index and S&P 500 ETF
# Read the daily prices and clean the data.

# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
#from MCForecastTools import MCSimulation

# %matplotlib inline

# %%
# LOAD ENV FILE
load_dotenv(r"C:\Users\juddm\OneDrive\Desktop\School\example.env")
# Out:
# True

# %%
# Setup Alpaca API environment
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2"
)

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp("2022-01-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["QQQ", "QCLN"]

# Get 3 year's worth of historical data for all stocks
index_df = api.get_bars(
    tickers,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
index_df.head(50)
# Out:
#                            close     high      low  trade_count     open  \
# timestamp
# 2022-01-03 05:00:00+00:00  70.08  70.1778  68.3450         3362  69.4990
# 2022-01-04 05:00:00+00:00  69.04  70.5500  67.5900         4818  70.5000
# 2022-01-05 05:00:00+00:00  65.21  68.9082  65.1000         3885  68.6600
# 2022-01-06 05:00:00+00:00  64.41  65.6200  62.7800         4927  65.0100
# 2022-01-07 05:00:00+00:00  63.59  65.7487  63.2000         3212  64.4900
# 2022-01-10 05:00:00+00:00  63.03  63.0800  60.6600         5873  62.4500
# 2022-01-11 05:00:00+00:00  64.51  64.7500  62.7700         3604  63.0300
# 2022-01-12 05:00:00+00:00  65.29  66.3700  64.4820         5423  65.5500
# 2022-01-13 05:00:00+00:00  63.26  66.4600  63.1100         3524  65.8600
# 2022-01-14 05:00:00+00:00  63.54  63.9100  62.1100         3906  62.5300
# 2022-01-18 05:00:00+00:00  61.14  63.1300  61.0500         4435  62.2300
# 2022-01-19 05:00:00+00:00  59.33  61.8100  59.2800         6219  61.3300
# ...

# %%
# Choose relevant columns
index_df = index_df [
    ["close", "symbol"]
]
index_df
# Out:
#                             close symbol
# timestamp
# 2022-01-03 05:00:00+00:00   70.08   QCLN
# 2022-01-04 05:00:00+00:00   69.04   QCLN
# 2022-01-05 05:00:00+00:00   65.21   QCLN
# 2022-01-06 05:00:00+00:00   64.41   QCLN
# 2022-01-07 05:00:00+00:00   63.59   QCLN
# ...                           ...    ...
# 2023-10-02 04:00:00+00:00  361.26    QQQ
# 2023-10-03 04:00:00+00:00  354.92    QQQ
# 2023-10-04 04:00:00+00:00  359.75    QQQ
# 2023-10-05 04:00:00+00:00  358.69    QQQ
# 2023-10-06 04:00:00+00:00  364.70    QQQ
#
# [886 rows x 2 columns]

# %%
# Reorganize the DataFrame
# Separate ticker data
QQQ = index_df[index_df["symbol"]=="QQQ"].drop("symbol", axis=1)
QCLN = index_df[index_df["symbol"]=="QCLN"].drop("symbol", axis=1)

# Concatenate the ticker DataFrames
index_df = pd.concat([QQQ, QCLN], axis=1, keys=["QQQ","QCLN"])

# Display sample data
index_df.head()
# Out:
#                               QQQ   QCLN
#                             close  close
# timestamp
# 2022-01-03 05:00:00+00:00  401.68  70.08
# 2022-01-04 05:00:00+00:00  396.47  69.04
# 2022-01-05 05:00:00+00:00  384.29  65.21
# 2022-01-06 05:00:00+00:00  384.02  64.41
# 2022-01-07 05:00:00+00:00  379.86  63.59

# %% [markdown]
# ## Combine the three portfolios?

# %%
# Join 3 datasets into a single DataFrame with columns for each portfolio's returns.
