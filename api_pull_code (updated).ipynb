# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
#from MCForecastTools import MCSimulation

# %matplotlib inline

# %%
# LOAD ENV FILE
load_dotenv(r"C:\Users\PC2\Documents\.env")
# Out:
# True

# %%
#api_key = os.getenv("NASDAQ_API_KEY")

# %%
#api_key

# %%
#request_url = "https://data.nasdaq.com/api/v3/datasets/WIKI/MSFT.json?rU4Jqzn3VCkREJgsHAPw"
#request_url = request_url + api_key

# %%
#response_data = requests.get(request_url)

# %%
#response_data.content

# %%
# Setup Alpaca API environment
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2"
)

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp("2023-10-03", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["TSLA", "ON", "ALB", "RIVN", "FSLR", "ENPH", "ENPH", "LCID", "OLED", "SEDG"]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
df_ticker = api.get_bars(
    tickers,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
df_ticker.head(50)
# Out:
#                               open      high       low   close     volume  \
# timestamp
# 2023-10-03 04:00:00+00:00  160.000  161.3000  155.1450  156.77    2515236
# 2023-10-04 04:00:00+00:00  157.560  158.8800  152.1300  158.40    2304428
# 2023-10-05 04:00:00+00:00  157.210  157.6700  152.0000  155.03    1948531
# 2023-10-06 04:00:00+00:00  154.660  161.1700  153.6600  159.84    1818781
# 2023-10-03 04:00:00+00:00  115.000  116.1300  111.4400  114.22    4964928
# 2023-10-04 04:00:00+00:00  114.760  120.0600  112.9000  117.18    5027013
# 2023-10-05 04:00:00+00:00  116.990  117.7500  112.4200  116.01    3477543
# 2023-10-06 04:00:00+00:00  113.980  119.6700  112.5000  119.16    3347958
# 2023-10-03 04:00:00+00:00  154.650  155.3300  149.6300  151.25    2858331
# 2023-10-04 04:00:00+00:00  151.400  152.8800  146.6100  151.82    3376488
# 2023-10-05 04:00:00+00:00  152.220  152.5000  143.5600  145.35    2998630
# ...

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp("2023-10-03", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["BEP", "ALGM", "AYI", "POWI", "WOLF", "ORA", "PLUG", "ENS", "AEIS", "LTHM"]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
df_ticker = api.get_bars(
    tickers,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
df_ticker.head(50)
# Out:
#                              open      high       low   close    volume  \
# timestamp
# 2023-10-03 04:00:00+00:00  101.81  102.8400   98.4200   98.95    248232
# 2023-10-04 04:00:00+00:00   99.26  100.7325   98.6600   99.18    177281
# 2023-10-05 04:00:00+00:00   99.61  100.1300   97.4600   97.68    201087
# 2023-10-06 04:00:00+00:00   96.93   99.4200   96.4750   98.82    200860
# 2023-10-03 04:00:00+00:00   31.54   31.6900   29.4800   29.98   3409830
# 2023-10-04 04:00:00+00:00   30.13   30.9800   29.8600   30.92   1663186
# 2023-10-05 04:00:00+00:00   30.84   30.9900   30.2100   30.37    824781
# 2023-10-06 04:00:00+00:00   29.98   31.1600   29.7600   30.92   1060488
# 2023-10-03 04:00:00+00:00  166.78  169.5700  165.8500  167.38    763422
# 2023-10-04 04:00:00+00:00  177.80  180.5550  171.2550  179.00   1335118
# 2023-10-05 04:00:00+00:00  179.27  181.7500  177.4600  179.00    581342
# 2023-10-06 04:00:00+00:00  177.73  182.7100  177.7300  181.66    344160
# ...

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp("2023-10-03", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["MP", "SQM", "ARRY", "ITRI", "SHLS", "FLNC", "BE", "RUN", "NXT", "NEP"]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
df_ticker = api.get_bars(
    tickers,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
df_ticker.head(50)
# Out:
#                               open     high      low   close    volume  \
# timestamp
# 2023-10-03 04:00:00+00:00  20.8400  20.9500  19.1350  19.545   7917439
# 2023-10-04 04:00:00+00:00  19.6900  20.3500  19.0850  20.330   7140455
# 2023-10-05 04:00:00+00:00  20.2300  20.2300  18.8100  18.830   7155251
# 2023-10-06 04:00:00+00:00  18.6000  20.1700  18.5300  19.750   7120694
# 2023-10-03 04:00:00+00:00  12.0100  12.0900  11.4200  11.540   7094992
# 2023-10-04 04:00:00+00:00  11.5700  11.6800  10.9700  11.380   5383017
# 2023-10-05 04:00:00+00:00  11.1800  11.2400  10.6750  10.740   5031578
# 2023-10-06 04:00:00+00:00  10.5600  11.1900  10.5250  11.130   4820536
# 2023-10-03 04:00:00+00:00  21.9200  22.0000  19.8500  20.420   2033107
# 2023-10-04 04:00:00+00:00  20.4600  21.1800  19.3850  21.100   1273822
# 2023-10-05 04:00:00+00:00  20.9800  20.9800  20.2100  20.620   1222469
# 2023-10-06 04:00:00+00:00  19.7400  21.1100  19.6500  20.780   1306673
# ...

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp("2023-10-03", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["AY", "VICR", "CWEN", "HASI", "CHPT", "MNTK", "RNW", "AMRC", "NVTS", "NOVA"]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
df_ticker = api.get_bars(
    tickers,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
df_ticker.head(50)
# Out:
#                              open     high      low  close    volume  \
# timestamp
# 2023-10-03 04:00:00+00:00  34.990  35.2850  33.7700  33.82    306396
# 2023-10-04 04:00:00+00:00  33.660  35.3300  33.5500  35.23    398236
# 2023-10-05 04:00:00+00:00  34.790  34.9900  32.9888  33.09    331447
# 2023-10-06 04:00:00+00:00  32.520  33.4390  31.6250  33.19    647071
# 2023-10-03 04:00:00+00:00  17.745  17.7450  16.9200  17.15   1542446
# 2023-10-04 04:00:00+00:00  17.280  17.6900  16.9100  17.10   1337253
# 2023-10-05 04:00:00+00:00  17.090  17.0900  16.4700  16.80   3535339
# 2023-10-06 04:00:00+00:00  16.710  17.8000  16.6900  17.65   1686078
# 2023-10-03 04:00:00+00:00   4.690   4.7000   4.2600   4.38  20882638
# 2023-10-04 04:00:00+00:00   4.390   4.4500   4.2000   4.40  11660470
# 2023-10-05 04:00:00+00:00   4.320   4.3500   4.1200   4.16  11575494
# 2023-10-06 04:00:00+00:00   4.080   4.3400   4.0500   4.31  11523015
# ...

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp("2023-10-03", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["BLDP", "SPWR", "CLNE", "LNZA", "AMPS", "GGR", "ALLG", "STEM", "FCEL", "LICY"]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
df_ticker = api.get_bars(
    tickers,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
df_ticker.head(50)
# Out:
#                             open    high     low  close   volume  trade_count  \
# timestamp
# 2023-10-03 04:00:00+00:00  2.380  2.7843  2.3200  2.550   349238         2282
# 2023-10-04 04:00:00+00:00  2.490  2.5500  2.0800  2.190   282735         2412
# 2023-10-05 04:00:00+00:00  2.200  2.2100  2.1000  2.140   123216          931
# 2023-10-06 04:00:00+00:00  2.180  2.1800  2.1000  2.160    58422          412
# 2023-10-03 04:00:00+00:00  4.720  4.7700  4.4700  4.520  1934142        13039
# 2023-10-04 04:00:00+00:00  4.560  4.6250  4.3809  4.430  1395241        10017
# 2023-10-05 04:00:00+00:00  4.380  4.4500  4.2900  4.370  1408017         8825
# 2023-10-06 04:00:00+00:00  4.320  4.7950  4.2850  4.640  1479853         8565
# 2023-10-03 04:00:00+00:00  3.370  3.4700  3.3100  3.400  2118487         8503
# 2023-10-04 04:00:00+00:00  3.380  3.5350  3.3100  3.520  3247293        10858
# 2023-10-05 04:00:00+00:00  3.480  3.4800  3.3500  3.410  1655692         7645
# ...

# %%
# Initial imports 
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
#from MCForecastTools import MCSimulation

# %matplotlib inline

# %%
# LOAD ENV FILE
load_dotenv(r"C:\Users\juddm\OneDrive\Desktop\School\example.env")
# Out:
# True

# %%
# Setup Alpaca API environment
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2"
)

# %%
# Set timeframe to "1Day"
timeframe = "1Day"

# Set start and end datetimes of 1 year, between now and 365 days ago.
start_date = pd.Timestamp("2023-10-03", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2023-10-06", tz="America/New_York").isoformat()

# Set the stock tickers
tickers = ["VOO", "QCLN"]

# Get 1 year's worth of historical data for all stocks
# HINT: Set "limit" to at least 10000 so all ticker rows are captured from get_bars()
index_df = api.get_bars(
    tickers,
    timeframe,
    start=start_date,
    end=end_date, limit = 10000
).df

# Display sample data
index_df.head(50)
# Out:
#                              open      high       low   close   volume  \
# timestamp
# 2023-10-03 04:00:00+00:00   40.91   40.9100   39.6418   39.86   159847
# 2023-10-04 04:00:00+00:00   39.84   40.8199   39.5866   40.70   130103
# 2023-10-05 04:00:00+00:00   40.21   40.2100   38.7775   38.89   304433
# 2023-10-06 04:00:00+00:00   38.42   39.8979   38.3001   39.80   206796
# 2023-10-03 04:00:00+00:00  390.58  391.9300  386.0300  387.39  6887856
# 2023-10-04 04:00:00+00:00  387.73  390.8500  386.4000  390.24  4335660
# 2023-10-05 04:00:00+00:00  389.89  390.7889  386.9500  389.91  3330512
# 2023-10-06 04:00:00+00:00  387.69  396.0850  386.4104  394.56  4897219
#
#                            trade_count        vwap symbol
# timestamp
# 2023-10-03 04:00:00+00:00         1839   39.995037   QCLN
# 2023-10-04 04:00:00+00:00         1202   40.299858   QCLN
# 2023-10-05 04:00:00+00:00         2267   39.107321   QCLN
# 2023-10-06 04:00:00+00:00         2088   39.329708   QCLN
# ...
